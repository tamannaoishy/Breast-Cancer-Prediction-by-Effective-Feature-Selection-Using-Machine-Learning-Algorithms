# %%
import pandas as pd

results_df = pd.read_csv('/content/drive/MyDrive/Thesis/Code/ANOVA F-test +Classifiers.ipynb')
results_rfecv_df = pd.read_csv('/content/drive/MyDrive/Thesis/Code/(RFE) with optimal Feature selection +Classifiers .ipynb')
results_etc_df = pd.read_csv('/content/drive/MyDrive/Thesis/Code/ExtraTrees+classifiers.ipynb')

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# Add a column to indicate the feature selection method for each DataFrame
results_df['Feature Selection'] = 'ANOVA F-test'
results_rfecv_df['Feature Selection'] = 'RFECV (RFE)'
results_etc_df['Feature Selection'] = 'ExtraTrees Top-k'

# Concatenate all results
combined_results = pd.concat([results_df, results_rfecv_df, results_etc_df], ignore_index=True)

# Optional: reorder columns for clarity
cols = ['Model', 'Feature Selection', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']
combined_results = combined_results[cols]

print("📊 Combined Model Performance Comparison:")
print(combined_results.round(4))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-356d8fa13152> in <cell line: 0>()
#      11 # Optional: reorder columns for clarity
#      12 cols = [ 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']
# ---> 13 combined_results = combined_results[cols]
#      14
#      15 print("📊 Combined Model Performance Comparison:")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
